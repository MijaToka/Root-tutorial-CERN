# %% [markdown]
# # 1. `ROOT` basics tutorial
#
# Let's start by importing root and some other libraries needed for the following:

# %%
import sys
import os
import ROOT
import numpy as np # library of mathematical functions
import pandas as pd # library for data storage
import matplotlib.pyplot as plt # library for basic plotting
import seaborn as sb # library for statistical plotting

# %% [markdown]
# We use ROOT to read the file containing the events and to check what is inside the it:
# * `TFile` is the ROOT library for the handling of files
# * `GetListOfKeys()` returns the list of names of the object contained in the file
# * `Get()` is the general function to get an object. It takes the name of the object as an input
# * `GetEntries()` takes no input and returns the number of entries in the object on which it is called

# %%
rfile = ROOT.TFile.Open('../data/SKIM_GGHH_NLO_cHHH1_xs.root')

for key in rfile.GetListOfKeys():
    name = key.GetName()
    entries = rfile.Get(name).GetEntries()
    print('{} : {}'.format(name,entries))
# Out:
# HTauTauTree : 26940

# %% [markdown]
# Inside the file there is a `TTree` named `HTauTauTree`.
#
# But what is a `TTree`? <br>
# A `TTree` represents a columnar dataset. Any C++ type can be stored in its columns. A `TTree`, often called in jargon tree, consists of a list of independent columns or branches, represented by the `TBranch` class. Behind each branch, buffers are allocated automatically by `ROOT`. Such buffers are automatically written to disk or kept in memory until the size stored in the attribute `fMaxVirtualSize` is reached. Variables of one branch are written to the same buffer. A branch buffer is automatically compressed if the file compression attribute is set (default). Branches may be written to different files (see `TBranch::SetFile`). <br>
# A full documentation about `TTree` can be found [here](https://root.cern.ch/doc/master/classTTree.html).
#
# But what is there inside this tree? <br>
# Let's check:

# %%
tree = rfile.Get('HTauTauTree')
tree.Print()
# Out:
# ******************************************************************************
# *Tree    :HTauTauTree: small tree for HH analysis                             *
# *Entries :    26940 : Total =        66834280 bytes  File  Size =   33190876 *
# *        :          : Tree compression factor =   2.01                       *
# ******************************************************************************
# *Br    0 :MC_weight : MC_weight/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       8167 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  13.33     *
# *............................................................................*
# *Br    1 :totalWeight : totalWeight/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      95674 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br    2 :prescaleWeight : prescaleWeight/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =       3272 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  33.28     *
# *............................................................................*
# *Br    3 :L1pref_weight : L1pref_weight/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =       2150 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.65     *
# *............................................................................*
# *Br    4 :PUjetID_SF : PUjetID_SF/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =      75643 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.44     *
# *............................................................................*
# *Br    5 :PUReweight : PUReweight/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =      42035 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.59     *
# *............................................................................*
# *Br    6 :bTagweightL : bTagweightL/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      92726 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Br    7 :bTagweightM : bTagweightM/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      90131 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.21     *
# *............................................................................*
# *Br    8 :bTagweightT : bTagweightT/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      90599 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br    9 :bTagweightReshape : bTagweightReshape/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      92771 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.17     *
# *............................................................................*
# *Br   10 :TTtopPtreweight : TTtopPtreweight/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       2176 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.05     *
# *............................................................................*
# *Br   11 :trigSF    : trigSF/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      91300 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.19     *
# *............................................................................*
# *Br   12 :trigSF_single : trigSF_single/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =       2150 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.65     *
# *............................................................................*
# *Br   13 :trigSF_cross : trigSF_cross/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =       2137 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.95     *
# *............................................................................*
# *Br   14 :VBFtrigSF : VBFtrigSF/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       2202 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  49.43     *
# *............................................................................*
# *Br   15 :FakeRateSF : FakeRateSF/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       2111 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.56     *
# *............................................................................*
# *Br   16 :jetFakeSF : jetFakeSF/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       5112 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  21.29     *
# *............................................................................*
# *Br   17 :IdAndIsoSF_MVA : IdAndIsoSF_MVA/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      24751 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   4.40     *
# *............................................................................*
# *Br   18 :IdAndIsoSF_deep : IdAndIsoSF_deep/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =      24060 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   4.53     *
# *............................................................................*
# *Br   19 :IdAndIsoSF_deep_pt : IdAndIsoSF_deep_pt/F                          *
# *Entries :    26940 : Total  Size=     109573 bytes  File Size  =       6438 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  16.92     *
# *............................................................................*
# *Br   20 :IdAndIsoAndFakeSF_MVA : IdAndIsoAndFakeSF_MVA/F                    *
# *Entries :    26940 : Total  Size=     109624 bytes  File Size  =      25211 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   4.32     *
# *............................................................................*
# *Br   21 :IdAndIsoAndFakeSF_deep : IdAndIsoAndFakeSF_deep/F                  *
# *Entries :    26940 : Total  Size=     109641 bytes  File Size  =      24514 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   4.45     *
# *............................................................................*
# *Br   22 :IdAndIsoAndFakeSF_deep_pt : IdAndIsoAndFakeSF_deep_pt/F            *
# *Entries :    26940 : Total  Size=     109692 bytes  File Size  =       6710 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  16.25     *
# *............................................................................*
# *Br   23 :FakeRateSF_MVA : FakeRateSF_MVA/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =       2883 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  37.77     *
# *............................................................................*
# *Br   24 :FakeRateSF_deep : FakeRateSF_deep/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       2850 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  38.22     *
# *............................................................................*
# *Br   25 :customTauIdSF : customTauIdSF/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =       2150 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.65     *
# *............................................................................*
# *Br   26 :DYscale_LL : DYscale_LL/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       2111 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.56     *
# *............................................................................*
# *Br   27 :DYscale_MM : DYscale_MM/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       2111 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.56     *
# *............................................................................*
# *Br   28 :DYscale_MH : DYscale_MH/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       2111 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.56     *
# *............................................................................*
# *Br   29 :DYscale_MTT : DYscale_MTT/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =       2124 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.25     *
# *............................................................................*
# *Br   30 :genZ_pt   : genZ_pt/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =       2072 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  52.52     *
# *............................................................................*
# *Br   31 :nBhadrons : nBhadrons/I                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       1970 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  55.25     *
# *............................................................................*
# *Br   32 :lheNOutPartons : lheNOutPartons/I                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =       2137 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.96     *
# *............................................................................*
# *Br   33 :lheNOutB  : lheNOutB/I                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =       2400 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  45.34     *
# *............................................................................*
# *Br   34 :EventNumber : EventNumber/l                                        *
# *Entries :    26940 : Total  Size=     217222 bytes  File Size  =      95292 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br   35 :RunNumber : RunNumber/I                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       2072 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  52.53     *
# *............................................................................*
# *Br   36 :isBoosted : isBoosted/I                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       8597 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  12.66     *
# *............................................................................*
# *Br   37 :isVBF     : isVBF/I                                                *
# *Entries :    26940 : Total  Size=     109352 bytes  File Size  =      12022 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   9.05     *
# *............................................................................*
# *Br   38 :isVBFtrigger : isVBFtrigger/I                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =       3053 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  35.66     *
# *............................................................................*
# *Br   39 :genDecMode1 : genDecMode1/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      13139 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   8.29     *
# *............................................................................*
# *Br   40 :genDecMode2 : genDecMode2/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      13171 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   8.27     *
# *............................................................................*
# *Br   41 :genMHH    : m_genMHH/F                                             *
# *Entries :    26940 : Total  Size=     109375 bytes  File Size  =      96179 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   42 :genCosth  : m_genCosth/F                                           *
# *Entries :    26940 : Total  Size=     109409 bytes  File Size  =     101413 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   43 :npv       : npv/I                                                  *
# *Entries :    26940 : Total  Size=     109318 bytes  File Size  =      33296 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   3.27     *
# *............................................................................*
# *Br   44 :npu       : npu/F                                                  *
# *Entries :    26940 : Total  Size=     109318 bytes  File Size  =      96151 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   45 :lumi      : lumi/I                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =      29604 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   3.67     *
# *............................................................................*
# *Br   46 :triggerbit : triggerbit/L                                          *
# *Entries :    26940 : Total  Size=     217205 bytes  File Size  =      29029 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   7.46     *
# *............................................................................*
# *Br   47 :pass_triggerbit : pass_triggerbit/I                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       3210 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  33.93     *
# *............................................................................*
# *Br   48 :cross_monitoring_trig : cross_monitoring_trig/O                    *
# *Entries :    26940 : Total  Size=      28798 bytes  File Size  =       1755 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  16.05     *
# *............................................................................*
# *Br   49 :rho       : rho/F                                                  *
# *Entries :    26940 : Total  Size=     109318 bytes  File Size  =      95233 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br   50 :pairType  : pairType/I                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =       2063 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  52.75     *
# *............................................................................*
# *Br   51 :isMC      : isMC/I                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =       2007 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  54.20     *
# *............................................................................*
# *Br   52 :isOS      : isOS/I                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =       4537 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  23.97     *
# *............................................................................*
# *Br   53 :met_phi   : met_phi/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      97635 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br   54 :met_et    : met_et/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      97475 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   55 :METx      : METx/F                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =     101546 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   56 :METy      : METy/F                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =     101552 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   57 :met_et_corr : met_et_corr/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      97540 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br   58 :met_cov00 : met_cov00/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =      94987 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br   59 :met_cov01 : met_cov01/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =     101964 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   60 :met_cov10 : met_cov10/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =     101964 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   61 :met_cov11 : met_cov11/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =      95008 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br   62 :mT1       : mT1/F                                                  *
# *Entries :    26940 : Total  Size=     109318 bytes  File Size  =      98646 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.10     *
# *............................................................................*
# *Br   63 :mT2       : mT2/F                                                  *
# *Entries :    26940 : Total  Size=     109318 bytes  File Size  =      98422 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br   64 :dau1_iso  : dau1_iso/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      85851 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.27     *
# *............................................................................*
# *Br   65 :dau1_eleMVAiso : dau1_eleMVAiso/I                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =       2035 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  53.52     *
# *............................................................................*
# *Br   66 :dau1_MVAiso : dau1_MVAiso/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =       1996 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  54.54     *
# *............................................................................*
# *Br   67 :dau1_MVAisoNew : dau1_MVAisoNew/I                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      15147 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   7.19     *
# *............................................................................*
# *Br   68 :dau1_MVAisoNewdR0p3 : dau1_MVAisoNewdR0p3/I                        *
# *Entries :    26940 : Total  Size=     109590 bytes  File Size  =       2100 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.89     *
# *............................................................................*
# *Br   69 :dau1_CUTiso : dau1_CUTiso/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      15867 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.86     *
# *............................................................................*
# *Br   70 :dau1_antiele : dau1_antiele/I                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      14246 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   7.64     *
# *............................................................................*
# *Br   71 :dau1_antimu : dau1_antimu/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =       2918 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  37.31     *
# *............................................................................*
# *Br   72 :dau1_deepTauVsJet : dau1_deepTauVsJet/I                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      13662 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   7.97     *
# *............................................................................*
# *Br   73 :dau1_deepTauVsEle : dau1_deepTauVsEle/I                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      15927 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.84     *
# *............................................................................*
# *Br   74 :dau1_deepTauVsMu : dau1_deepTauVsMu/I                              *
# *Entries :    26940 : Total  Size=     109539 bytes  File Size  =       2479 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  43.94     *
# *............................................................................*
# *Br   75 :dau1_photonPtSumOutsideSignalCone :                                *
# *         | dau1_photonPtSumOutsideSignalCone/F                              *
# *Entries :    26940 : Total  Size=     109828 bytes  File Size  =      39563 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.76     *
# *............................................................................*
# *Br   76 :dau1_byLooseCombinedIsolationDeltaBetaCorr3Hits :                  *
# *         | dau1_byLooseCombinedIsolationDeltaBetaCorr3Hits/O                *
# *Entries :    26940 : Total  Size=      29240 bytes  File Size  =       8087 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   3.53     *
# *............................................................................*
# *Br   77 :dau1_byMediumCombinedIsolationDeltaBetaCorr3Hits :                 *
# *         | dau1_byMediumCombinedIsolationDeltaBetaCorr3Hits/O               *
# *Entries :    26940 : Total  Size=      29257 bytes  File Size  =       6208 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   4.60     *
# *............................................................................*
# *Br   78 :dau1_byTightCombinedIsolationDeltaBetaCorr3Hits :                  *
# *         | dau1_byTightCombinedIsolationDeltaBetaCorr3Hits/O                *
# *Entries :    26940 : Total  Size=      29240 bytes  File Size  =       6195 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   4.60     *
# *............................................................................*
# *Br   79 :dau1_pt   : dau1_pt/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      95337 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br   80 :dau1_eta  : dau1_eta/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =     100774 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   81 :dau1_phi  : dau1_phi/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =     100966 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   82 :dau1_e    : dau1_e/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      96665 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   83 :dau1_flav : dau1_flav/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =      12591 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   8.64     *
# *............................................................................*
# *Br   84 :dau1_dxy  : dau1_dxy/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      88182 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.23     *
# *............................................................................*
# *Br   85 :dau1_dz   : dau1_dz/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      89166 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.22     *
# *............................................................................*
# *Br   86 :dau1_decayMode : dau1_decayMode/I                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      17019 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.40     *
# *............................................................................*
# *Br   87 :genmatched1_pt : genmatched1_pt/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =       2163 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.35     *
# *............................................................................*
# *Br   88 :genmatched1_eta : genmatched1_eta/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       2176 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.05     *
# *............................................................................*
# *Br   89 :genmatched1_phi : genmatched1_phi/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       2176 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.05     *
# *............................................................................*
# *Br   90 :genmatched1_e : genmatched1_e/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =       2150 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.65     *
# *............................................................................*
# *Br   91 :genmatched2_pt : genmatched2_pt/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =       2163 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.35     *
# *............................................................................*
# *Br   92 :genmatched2_eta : genmatched2_eta/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       2176 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.05     *
# *............................................................................*
# *Br   93 :genmatched2_phi : genmatched2_phi/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =       2176 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.05     *
# *............................................................................*
# *Br   94 :genmatched2_e : genmatched2_e/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =       2150 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  50.65     *
# *............................................................................*
# *Br   95 :hasgenmatch1 : hasgenmatch1/O                                      *
# *Entries :    26940 : Total  Size=      28645 bytes  File Size  =       2106 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  13.32     *
# *............................................................................*
# *Br   96 :hasgenmatch2 : hasgenmatch2/O                                      *
# *Entries :    26940 : Total  Size=      28645 bytes  File Size  =       3650 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   7.69     *
# *............................................................................*
# *Br   97 :dau2_iso  : dau2_iso/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      92031 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.18     *
# *............................................................................*
# *Br   98 :dau2_MVAiso : dau2_MVAiso/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =       1996 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  54.54     *
# *............................................................................*
# *Br   99 :dau2_MVAisoNew : dau2_MVAisoNew/I                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      19957 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   5.46     *
# *............................................................................*
# *Br  100 :dau2_MVAisoNewdR0p3 : dau2_MVAisoNewdR0p3/I                        *
# *Entries :    26940 : Total  Size=     109590 bytes  File Size  =       2100 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.89     *
# *............................................................................*
# *Br  101 :dau2_CUTiso : dau2_CUTiso/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      17436 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.24     *
# *............................................................................*
# *Br  102 :dau2_antiele : dau2_antiele/I                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      15230 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   7.15     *
# *............................................................................*
# *Br  103 :dau2_antimu : dau2_antimu/I                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =       3131 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  34.77     *
# *............................................................................*
# *Br  104 :dau2_deepTauVsJet : dau2_deepTauVsJet/I                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      21640 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   5.03     *
# *............................................................................*
# *Br  105 :dau2_deepTauVsEle : dau2_deepTauVsEle/I                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      18080 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.03     *
# *............................................................................*
# *Br  106 :dau2_deepTauVsMu : dau2_deepTauVsMu/I                              *
# *Entries :    26940 : Total  Size=     109539 bytes  File Size  =       2785 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  39.11     *
# *............................................................................*
# *Br  107 :dau2_photonPtSumOutsideSignalCone :                                *
# *         | dau2_photonPtSumOutsideSignalCone/F                              *
# *Entries :    26940 : Total  Size=     109828 bytes  File Size  =      55944 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.95     *
# *............................................................................*
# *Br  108 :dau2_byLooseCombinedIsolationDeltaBetaCorr3Hits :                  *
# *         | dau2_byLooseCombinedIsolationDeltaBetaCorr3Hits/O                *
# *Entries :    26940 : Total  Size=      29240 bytes  File Size  =       8249 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   3.46     *
# *............................................................................*
# *Br  109 :dau2_byMediumCombinedIsolationDeltaBetaCorr3Hits :                 *
# *         | dau2_byMediumCombinedIsolationDeltaBetaCorr3Hits/O               *
# *Entries :    26940 : Total  Size=      29257 bytes  File Size  =       7601 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   3.75     *
# *............................................................................*
# *Br  110 :dau2_byTightCombinedIsolationDeltaBetaCorr3Hits :                  *
# *         | dau2_byTightCombinedIsolationDeltaBetaCorr3Hits/O                *
# *Entries :    26940 : Total  Size=      29240 bytes  File Size  =       7588 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   3.76     *
# *............................................................................*
# *Br  111 :dau2_pt   : dau2_pt/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      94750 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br  112 :dau2_eta  : dau2_eta/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =     100903 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  113 :dau2_phi  : dau2_phi/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =     100992 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  114 :dau2_e    : dau2_e/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      96463 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  115 :dau2_flav : dau2_flav/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =      12613 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   8.63     *
# *............................................................................*
# *Br  116 :dau2_dxy  : dau2_dxy/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      88617 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.23     *
# *............................................................................*
# *Br  117 :dau2_dz   : dau2_dz/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      89700 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.21     *
# *............................................................................*
# *Br  118 :dau2_decayMode : dau2_decayMode/I                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      17404 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.26     *
# *............................................................................*
# *Br  119 :bjet1_pt  : bjet1_pt/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      97280 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  120 :bjet1_eta : bjet1_eta/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =     100948 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  121 :bjet1_phi : bjet1_phi/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =     101034 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  122 :bjet1_e   : bjet1_e/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      97451 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  123 :bjet1_bID : bjet1_bID/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =      91192 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.19     *
# *............................................................................*
# *Br  124 :bjet1_bID_deepCSV : bjet1_bID_deepCSV/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      94479 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br  125 :bjet1_bID_deepFlavor : bjet1_bID_deepFlavor/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =      91716 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.19     *
# *............................................................................*
# *Br  126 :bjet1_cID_deepFlavor : bjet1_cID_deepFlavor/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =     102242 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br  127 :bjet1_CvsL : bjet1_CvsL/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =      94637 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br  128 :bjet1_CvsB : bjet1_CvsB/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =     102415 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br  129 :bjet1_HHbtag : bjet1_HHbtag/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      85505 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.27     *
# *............................................................................*
# *Br  130 :bjet1_bMVAID : bjet1_bMVAID/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      87382 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.25     *
# *............................................................................*
# *Br  131 :bjet1_PUjetIDupdated : bjet1_PUjetIDupdated/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =      81311 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.34     *
# *............................................................................*
# *Br  132 :bjet1_flav : bjet1_flav/I                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       4354 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  25.00     *
# *............................................................................*
# *Br  133 :bjet1_pt_raw : bjet1_pt_raw/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      97332 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  134 :bjet1_hasgenjet : bjet1_hasgenjet/O                                *
# *Entries :    26940 : Total  Size=      28696 bytes  File Size  =       1677 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  16.75     *
# *............................................................................*
# *Br  135 :bjet1_JER : bjet1_JER/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =      96831 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  136 :bjet1_gen_matched : bjet1_gen_matched/O                            *
# *Entries :    26940 : Total  Size=      28730 bytes  File Size  =       4169 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   6.75     *
# *............................................................................*
# *Br  137 :bjet2_pt  : bjet2_pt/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      97851 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  138 :bjet2_eta : bjet2_eta/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =     101032 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  139 :bjet2_phi : bjet2_phi/F                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =     101015 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  140 :bjet2_e   : bjet2_e/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      97817 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  141 :bjet2_bID : bjet2m_bID/F                                           *
# *Entries :    26940 : Total  Size=     109423 bytes  File Size  =      95779 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br  142 :bjet2_bID_deepCSV : bjet2_bID_deepCSV/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      97497 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  143 :bjet2_bID_deepFlavor : bjet2_bID_deepFlavor/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =      98579 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  144 :bjet2_cID_deepFlavor : bjet2_cID_deepFlavor/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =     100806 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  145 :bjet2_CvsL : bjet2_CvsL/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =      97839 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  146 :bjet2_CvsB : bjet2_CvsB/F                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =     100180 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br  147 :bjet2_HHbtag : bjet2_HHbtag/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      89236 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  148 :bjet2_bMVAID : bjet2_bMVAID/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =      90207 *
# ...
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  405 :dau2_z    : dau2_z/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      46637 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  406 :bjet1_z   : bjet1_z/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      46624 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  407 :bjet2_z   : bjet2_z/F                                              *
# *Entries :    26940 : Total  Size=     109386 bytes  File Size  =      46639 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  408 :tauH_z    : tauH_z/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      46688 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  409 :bH_z      : bH_z/F                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =      46611 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  410 :HH_z      : HH_z/F                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =      46595 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.33     *
# *............................................................................*
# *Br  411 :HH_zV     : HH_zV/F                                                *
# *Entries :    26940 : Total  Size=     109352 bytes  File Size  =      46111 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.36     *
# *............................................................................*
# *Br  412 :HH_A      : HH_A/F                                                 *
# *Entries :    26940 : Total  Size=     109335 bytes  File Size  =      44801 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br  413 :BDT_channel : BDT_channel/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =       2112 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  51.55     *
# *............................................................................*
# *Br  414 :tauH_MET_pt : tauH_MET_pt/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      96377 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  415 :dau2_MET_deltaEta : dau2_MET_deltaEta/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      98161 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  416 :bH_MET_deltaEta : bH_MET_deltaEta/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =      98218 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  417 :bH_MET_deltaR : bH_MET_deltaR/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =      95907 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br  418 :bH_tauH_MET_deltaR : bH_tauH_MET_deltaR/F                          *
# *Entries :    26940 : Total  Size=     109573 bytes  File Size  =      91841 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.19     *
# *............................................................................*
# *Br  419 :ditau_deltaR_per_tauH_MET_pt : ditau_deltaR_per_tauH_MET_pt/F      *
# *Entries :    26940 : Total  Size=     109743 bytes  File Size  =      94351 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.16     *
# *............................................................................*
# *Br  420 :p_zeta    : p_zeta/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      96703 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  421 :p_zeta_visible : p_zeta_visible/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      96932 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  422 :mT_tauH_MET : mT_tauH_MET/F                                        *
# *Entries :    26940 : Total  Size=     109454 bytes  File Size  =      98865 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.10     *
# *............................................................................*
# *Br  423 :mT_tauH_SVFIT_MET : mT_tauH_SVFIT_MET/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      99068 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.10     *
# *............................................................................*
# *Br  424 :mT_total  : mT_total/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      97024 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  425 :BDT_ditau_deltaPhi : m_BDT_ditau_deltaPhi/F                        *
# *Entries :    26940 : Total  Size=     109579 bytes  File Size  =     100078 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br  426 :BDT_dib_abs_deltaPhi : BDT_dib_abs_deltaPhi/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =      98086 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  427 :BDT_dib_deltaPhi : BDT_dib_deltaPhi/F                              *
# *Entries :    26940 : Total  Size=     109539 bytes  File Size  =     100861 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  428 :BDT_dau1MET_deltaPhi : BDT_dau1MET_deltaPhi/F                      *
# *Entries :    26940 : Total  Size=     109607 bytes  File Size  =     102195 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br  429 :BDT_tauHsvfitMet_abs_deltaPhi : BDT_tauHsvfitMet_abs_deltaPhi/F    *
# *Entries :    26940 : Total  Size=     109760 bytes  File Size  =      99900 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br  430 :BDT_tauHsvfitMet_deltaPhi : BDT_tauHsvfitMet_deltaPhi/F            *
# *Entries :    26940 : Total  Size=     109692 bytes  File Size  =     102597 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br  431 :BDT_bHMet_deltaPhi : BDT_bHMet_deltaPhi/F                          *
# *Entries :    26940 : Total  Size=     109573 bytes  File Size  =      99797 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.09     *
# *............................................................................*
# *Br  432 :BDT_HHsvfit_abs_deltaPhi : BDT_HHsvfit_abs_deltaPhi/F              *
# *Entries :    26940 : Total  Size=     109675 bytes  File Size  =      90841 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.20     *
# *............................................................................*
# *Br  433 :BDT_HT20  : BDT_HT20/F                                             *
# *Entries :    26940 : Total  Size=     109403 bytes  File Size  =      90139 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.21     *
# *............................................................................*
# *Br  434 :BDT_topPairMasses : BDT_topPairMasses/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      94543 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br  435 :BDT_topPairMasses2 : BDT_topPairMasses2/F                          *
# *Entries :    26940 : Total  Size=     109573 bytes  File Size  =      94511 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br  436 :BDT_MX    : BDT_MX/F                                               *
# *Entries :    26940 : Total  Size=     109369 bytes  File Size  =      96211 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  437 :BDT_bH_tauH_MET_InvMass : BDT_bH_tauH_MET_InvMass/F                *
# *Entries :    26940 : Total  Size=     109658 bytes  File Size  =      96613 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  438 :BDT_bH_tauH_SVFIT_InvMass : BDT_bH_tauH_SVFIT_InvMass/F            *
# *Entries :    26940 : Total  Size=     109692 bytes  File Size  =      96603 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  439 :BDT_bH_tauH_InvMass : BDT_bH_tauH_InvMass/F                        *
# *Entries :    26940 : Total  Size=     109590 bytes  File Size  =      95878 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*
# *Br  440 :BDT_total_CalcPhi : BDT_total_CalcPhi/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      98225 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  441 :BDT_ditau_CalcPhi : BDT_ditau_CalcPhi/F                            *
# *Entries :    26940 : Total  Size=     109556 bytes  File Size  =      97799 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  442 :BDT_dib_CalcPhi : BDT_dib_CalcPhi/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =      98147 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  443 :BDT_MET_tauH_SVFIT_cosTheta : BDT_MET_tauH_SVFIT_cosTheta/F        *
# *Entries :    26940 : Total  Size=     109726 bytes  File Size  =      97656 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  444 :BDT_MET_bH_cosTheta : BDT_MET_bH_cosTheta/F                        *
# *Entries :    26940 : Total  Size=     109590 bytes  File Size  =      91719 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.19     *
# *............................................................................*
# *Br  445 :BDT_b1_bH_cosTheta : BDT_b1_bH_cosTheta/F                          *
# *Entries :    26940 : Total  Size=     109573 bytes  File Size  =     100927 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  446 :BDT_tauH_SVFIT_reson_cosTheta : BDT_tauH_SVFIT_reson_cosTheta/F    *
# *Entries :    26940 : Total  Size=     109760 bytes  File Size  =     101578 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br  447 :VBFjj_dEtaSign : VBFjj_dEtaSign/F                                  *
# *Entries :    26940 : Total  Size=     109505 bytes  File Size  =      46579 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.34     *
# *............................................................................*
# *Br  448 :VBFjet2_PUjetID : VBFjet2_PUjetID/F                                *
# *Entries :    26940 : Total  Size=     109522 bytes  File Size  =      44636 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.44     *
# *............................................................................*
# *Br  449 :bH_VBF1_deltaEta : bH_VBF1_deltaEta/F                              *
# *Entries :    26940 : Total  Size=     109539 bytes  File Size  =      45249 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   2.41     *
# *............................................................................*
# *Br  450 :dib_dEtaSign : dib_dEtaSign/F                                      *
# *Entries :    26940 : Total  Size=     109471 bytes  File Size  =     102350 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.06     *
# *............................................................................*
# *Br  451 :isTau1real : isTau1real/I                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       2743 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  39.68     *
# *............................................................................*
# *Br  452 :isTau2real : isTau2real/I                                          *
# *Entries :    26940 : Total  Size=     109437 bytes  File Size  =       4854 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  22.43     *
# *............................................................................*
# *Br  453 :nRealTaus : nRealTaus/I                                            *
# *Entries :    26940 : Total  Size=     109420 bytes  File Size  =       5150 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=  21.13     *
# *............................................................................*
# *Br  454 :DNNoutSM_kl_1 : DNNoutSM_kl_1/F                                    *
# *Entries :    26940 : Total  Size=     109488 bytes  File Size  =      95601 *
# *Baskets :       13 : Basket Size=      32000 bytes  Compression=   1.14     *
# *............................................................................*

# %% [markdown]
# But `PyROOT` can do much more for you than simply providing access to `C++` libraries from `Python`. You can also inject efficient `C++` code into your `Python` program to speed up potentially slow parts of your program!

# %%
ROOT.gInterpreter.Declare('''
int my_heavy_computation(std::string x) {
    // heavy computation goes here
    return x.length();
}
''')

# Functions and object made available via the interpreter are accessible from
# the ROOT module
y = ROOT.my_heavy_computation("the ultimate answer to life and everything")
print(y) # Guess the result!
# Out:
# 42
# input_line_130:2:5: error: redefinition of 'my_heavy_computation'
# int my_heavy_computation(std::string x) {
#     ^
# input_line_93:2:5: note: previous definition is here
# int my_heavy_computation(std::string x) {
#     ^

# %% [markdown]
# ## 1.1 Plotting and fitting

# %% [markdown]
#  Now that we have seen how to open and inspect a tree, let's see how to plot what is contained in it.

# %%
# Make global style changes

# Prevent memory leaks by checking and deleting existing objects
if ROOT.gROOT.FindObject("c"):
    ROOT.gROOT.FindObject("c").Close()
if ROOT.gROOT.FindObject("h"):
    ROOT.gROOT.FindObject("h").Delete()
    
ROOT.gStyle.SetOptStat(0) # Disable the statistics box
ROOT.gStyle.SetTextFont(42)

# Create a canvas
c = ROOT.TCanvas('c', 'dau1_pt', 600, 400)

# Create a histogram and draw it
h = ROOT.TH1F('h', ';dau1_pt; N_{Events}', 100, 50, 350)
tree.Draw("dau1_pt>>h")

# Let's add some CMS style headline
label = ROOT.TLatex()
label.SetNDC(True)
label.SetTextSize(0.040)
label.DrawLatex(0.10, 0.92, '#bf{CMS preliminary}')
label.DrawLatex(0.58, 0.92, '#sqrt{s} = 13 TeV, L_{int} = 59.7 fb^{-1}')

# show interactively

c.Draw()
# Out:
# <div id="root_plot_1744382002005" style="width: 600px; height: 400px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1744382002005(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":12.4999972060321,"fY1":-165.112512301841,"fX2":387.500002793968,"fY2":1486.01251230184,"fXtoAbsPixelk":-19.866661930084,"fXtoPixelk":-19.866661930084,"fXtoPixel":1.58933330965042,"fYtoAbsPixelk":334.799997782707,"fYtoPixelk":334.799997782707,"fYtoPixel":-0.225300927826038,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":372,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":12.4999972060321,"fPixeltoXk":12.4999972060321,"fPixeltoX":0.629194640248214,"fAbsPixeltoYk":1486.01251230184,"fPixeltoYk":-165.112512301841,"fPixeltoY":-4.43850813065506,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":50,"fUymin":0,"fUxmax":350,"fUymax":1320.9,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c","fTitle":"dau1_pt","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":13.33333,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":372,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113 ...

# %% [markdown]
# Now that we have seen this let's try and fill a histogram starting from the information iside a dataframe.
#
# Instead of using `uproot` this time we create a dataframe and fill it iteratively looping on the events contained in the tree.

# %%
Nevents = tree.GetEntries() # get the number of events inside the tree 

# create a dataframe that will contain the information we need
dau1df = pd.DataFrame(columns = ["dau1_pt", "dau1_eta", "dau1_phi", "dau1_flav"], index = range(Nevents))
dau2df = pd.DataFrame(columns = ["dau2_pt", "dau2_eta", "dau2_phi", "dau2_falv"], index = range(Nevents))

for i in range(Nevents):
    tree.GetEntry(i)
    dau1df["dau1_pt"][i] = tree.dau1_pt
    dau1df["dau1_eta"][i] = tree.dau1_eta
    dau1df["dau1_phi"][i] = tree.dau1_phi
    dau1df["dau1_flav"][i] = tree.dau1_flav
    dau2df["dau2_pt"][i] = tree.dau1_pt
    dau2df["dau2_eta"][i] = tree.dau1_eta
    dau2df["dau2_phi"][i] = tree.dau1_phi
    dau2df["dau2_eta"][i] = tree.dau1_flav

dau1df.head()
# Out:
# /tmp/ipykernel_47604/3355413601.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau1df["dau1_pt"][i] = tree.dau1_pt
# /tmp/ipykernel_47604/3355413601.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau1df["dau1_eta"][i] = tree.dau1_eta
# /tmp/ipykernel_47604/3355413601.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau1df["dau1_phi"][i] = tree.dau1_phi
# /tmp/ipykernel_47604/3355413601.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau1df["dau1_flav"][i] = tree.dau1_flav
# /tmp/ipykernel_47604/3355413601.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau2df["dau2_pt"][i] = tree.dau1_pt
# /tmp/ipykernel_47604/3355413601.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau2df["dau2_eta"][i] = tree.dau1_eta
# /tmp/ipykernel_47604/3355413601.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau2df["dau2_phi"][i] = tree.dau1_phi
# /tmp/ipykernel_47604/3355413601.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dau2df["dau2_eta"][i] = tree.dau1_flav
#       dau1_pt  dau1_eta  dau1_phi dau1_flav
# 0    57.84473  1.398397 -1.365659       3.0
# 1  195.437286 -0.407139  2.612768       3.0
# 2   77.581429 -1.428748  2.102256      -3.0
# 3   63.698456  0.161933  2.548742      -3.0
# 4   47.504292 -1.069206  -1.16261      -3.0

# %% [markdown]
# As you can see doing this takes a pretty long time!! So you might consider doing the reading of the `ROOT` file only once, you save the info inside a `.csv` file and then from then on you just read the `.csv` file which is a way faster method of reading data. Now this has the disadvantage that you will not be able to use the `ROOT` libraries on it.

# %% [markdown]
# Now that we have the DataFrame ready we can fill the histogram looping on the data inside the DataFrame.

# %%
# Prevent memory leaks by checking and deleting existing objects
if ROOT.gROOT.FindObject("c1"):
    ROOT.gROOT.FindObject("c1").Close()
if ROOT.gROOT.FindObject("h1"):
    ROOT.gROOT.FindObject("h1").Delete()

# Create a canvas
c1 = ROOT.TCanvas('c1', 'dau1_pt', 600, 400)

# Create a histogram and draw it
h1 = ROOT.TH1F('h1', ';#tau_{h}^{(1)} p_{T}; N_{Events}', 100, 50, 350)
for pt in dau1df["dau1_pt"]:
    if pt > 50: # I put this cut just for the fitting purpose
        h1.Fill(pt)
h1.Draw()
    
# Let's add some CMS style headline
label = ROOT.TLatex()
label.SetNDC(True)
label.SetTextSize(0.040)
label.DrawLatex(0.10, 0.92, '#bf{CMS preliminary}')
label.DrawLatex(0.58, 0.92, '#sqrt{s} = 13 TeV, L_{int} = 59.7 fb^{-1}')

# show interactively
c1.Draw()
# Out:
# <div id="root_plot_1744382144380" style="width: 600px; height: 400px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1744382144380(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":12.4999972060321,"fY1":-165.112512301841,"fX2":387.500002793968,"fY2":1486.01251230184,"fXtoAbsPixelk":-19.866661930084,"fXtoPixelk":-19.866661930084,"fXtoPixel":1.58933330965042,"fYtoAbsPixelk":334.799997782707,"fYtoPixelk":334.799997782707,"fYtoPixel":-0.225300927826038,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":372,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":12.4999972060321,"fPixeltoXk":12.4999972060321,"fPixeltoX":0.629194640248214,"fAbsPixeltoYk":1486.01251230184,"fPixeltoYk":-165.112512301841,"fPixeltoY":-4.43850813065506,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":50,"fUymin":0,"fUxmax":350,"fUymax":1320.9,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"dau1_pt","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":13.33333,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":372,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;11 ...

# %% [markdown]
# Now that we have a plot we can try to fit it with user defined functions using `ROOT`. We do it like this:

# %%
# Fit an inverse exponential function to the data
f = ROOT.TF1('f', '[0] * exp(-[1]*x) + [2]')
h1.Fit(f)

c1.Draw()
# Out:
# ****************************************
#          Invalid FitResult  (status = 3 )
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =        20377
# NDf                       =           97
# Edm                       =      24.8122
# NCalls                    =           94
# p0                        =       14.854   +/-   16.7023
# p1                        =  0.000241336   +/-   36.0678
# p2                        =      2.29739   +/-   4.0951
# Warning in <Fit>: Abnormal termination of minimization.
# <div id="root_plot_1744382144827" style="width: 600px; height: 400px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1744382144827(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":12.4999972060321,"fY1":-165.112512301841,"fX2":387.500002793968,"fY2":1486.01251230184,"fXtoAbsPixelk":-19.866661930084,"fXtoPixelk":-19.866661930084,"fXtoPixel":1.58933330965042,"fYtoAbsPixelk":334.799997782707,"fYtoPixelk":334.799997782707,"fYtoPixel":-0.225300927826038,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":372,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":12.4999972060321,"fPixeltoXk":12.4999972060321,"fPixeltoX":0.629194640248214,"fAbsPixeltoYk":1486.01251230184,"fPixeltoYk":-165.112512301841,"fPixeltoY":-4.43850813065506,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":50,"fUymin":0,"fUxmax":350,"fUymax":1320.9,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"dau1_pt","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":13.33333,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":372,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;11 ...

# %% [markdown]
# Why has the fit failed? Hint: what is the weak spot of every minimization?

# %%
# Fit an inverse exponential function to the data
f = ROOT.TF1('f', '[0] * exp(-[1]*x) + [2]')
f.SetParameters(4000, 0.02, 0)
h1.Fit(f)

c1.Draw()
# Out:
# ****************************************
# Minimizer is Minuit2 / Migrad
# Chi2                      =      131.163
# NDf                       =           97
# Edm                       =  5.09852e-08
# NCalls                    =           80
# p0                        =      4238.92   +/-   76.5495
# p1                        =    0.0216982   +/-   0.000189553
# p2                        =      1.54596   +/-   0.552721
# <div id="root_plot_1744382144961" style="width: 600px; height: 400px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1744382144961(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":12.4999972060321,"fY1":-182.193300638906,"fX2":387.500002793968,"fY2":1639.73959715448,"fXtoAbsPixelk":-19.866661930084,"fXtoPixelk":-19.866661930084,"fXtoPixel":1.58933330965042,"fYtoAbsPixelk":334.799997782707,"fYtoPixelk":334.799997782707,"fYtoPixel":-0.204178760068794,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":372,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":12.4999972060321,"fPixeltoXk":12.4999972060321,"fPixeltoX":0.629194640248214,"fAbsPixeltoYk":1639.73959715448,"fPixeltoYk":-182.193300638906,"fPixeltoY":-4.89766908008976,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":50,"fUymin":0,"fUxmax":350,"fUymax":1457.54629651558,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"dau1_pt","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":13.33333,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":372,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200 ...

# %% [markdown]
# A very cool feature is the `%jsroot on` magic, which enables ROOT’s JavaScript integration! This allows you to interact with the visualization such as you are used to it from the interactive graphics in the Python prompt.

# %%
# %jsroot on
c1.Draw()
# Out:
# <div id="root_plot_1744382145080" style="width: 600px; height: 400px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1744382145080(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":12.4999972060321,"fY1":-182.193300638906,"fX2":387.500002793968,"fY2":1639.73959715448,"fXtoAbsPixelk":-19.866661930084,"fXtoPixelk":-19.866661930084,"fXtoPixel":1.58933330965042,"fYtoAbsPixelk":334.799997782707,"fYtoPixelk":334.799997782707,"fYtoPixel":-0.204178760068794,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":372,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":12.4999972060321,"fPixeltoXk":12.4999972060321,"fPixeltoX":0.629194640248214,"fAbsPixeltoYk":1639.73959715448,"fPixeltoYk":-182.193300638906,"fPixeltoY":-4.89766908008976,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":50,"fUymin":0,"fUxmax":350,"fUymax":1457.54629651558,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"c1","fTitle":"dau1_pt","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":13.33333,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":372,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200 ...

# %%
# %jsroot off

# %% [markdown]
# ## 1.2 `RDataFrame` data handling

# %% [markdown]
# `RDataFrame` is `ROOT`’s high-level (and __very new__) interface for efficient data analysis. With `RDataFrame`, it is possible to read, select, modify and write `ROOT` data, as well as easily produce histograms, cut-flow reports and other results. In this and the following sections, you will learn how to perform data analysis with `RDataFrame`, running all your tasks efficiently on multiple threads!
#
# `ROOT` tries to make parallelization as simple as possible for you. For this reason, we offer the feature `ROOT.EnableImplicitMT(N)`, which enables thread safety for the relevant classes and runs parallelized parts of `ROOT`, such as `RDataFrame`, implicitely on `N` threads:

# %%
# Enable multi-threading with the specified amount of threads (let's start with just one)
# Note that older ROOT versions require to write ROOT.ROOT.EnableImplicitMT()
ROOT.ROOT.EnableImplicitMT(1)

# Or enable multi-threading with an auto-detected amount of threads
#ROOT.ROOT.EnableImplicitMT()

# %% [markdown]
# A possible way to construct an `RDataFrame` is passing one (ore more) filepaths and the name of the dataset (i.e. the name of the `TTree` object in the file, which is called `HTauTauTree` for us).

# %%
df = ROOT.RDataFrame("HTauTauTree", "../data/SKIM_GGHH_NLO_cHHH1_xs.root")

# %% [markdown]
# Next, you can apply selections and other transormations to the dataframe. The first basic transformation is applying cuts with the `Filter` method. Note that each transformation returns a new, transformed dataframe and does not change the dataframe object itself!

# %%
# For simplicity, select only events with exactly two muons and require opposite charge
df_ptCut = df.Filter("dau1_pt > 50 && dau2_pt > 50", "Events where both taus have pT > 50 GeV")

# %% [markdown]
# The next code block uses `PyROOT` to inject a `C++` implementation of the $\Delta R = \sqrt{(\Delta\phi)^2+(\Delta\eta)^2}$  computation. The name of the just-in-time compiled function can be used in the `Define` method to add a new column to the dataset, which will contain the angular separation.

# %%
# Perform the computation of the angular separation in C++
ROOT.gInterpreter.Declare('''
float ComputeDeltaR(Double_t eta1, Double_t phi1, Double_t eta2, Double_t phi2) {
    return sqrt((eta1-eta2)*(eta1-eta2) + (phi1-phi2)*(phi1-phi2));
}
''')

# Add the result of the computation to the dataframe
df_dR = df_ptCut.Define("dR", "ComputeDeltaR(dau1_eta, dau1_phi, dau2_eta, dau2_phi)")

# %% [markdown]
# At any point, you can book the computation of results, e.g., histograms or a report. Both of them are added below. Please note that `RDataFrame` is lazy! This means that the computation does not run right away, when you book a histogram, but you can accumulate multiple results and compute all of them in one go. The computation of all booked results is triggered only when you actually access one of the results!

# %%
h_dR = df_dR.Histo1D(("dR",";#DeltaR(#tau,#tau);N_{Events}", 25, 0, 10), "dR")
report = df_dR.Report()

# %% [markdown]
# As explained above, accessing a dataframe result triggers the computation (sometimes called “event loop”) of all results booked up to that point. Here, this happens when we draw the histogram. However, you just have to remember to book all results first and then start working with the results so that they can all be computed in one go!

# %%
c2 = ROOT.TCanvas("c2", "dR", 600, 400)
h_dR.Draw()

label = ROOT.TLatex()
label.SetNDC(True)
label.SetTextSize(0.040)
label.DrawLatex(0.100, 0.920, "#bf{CMS Preliminary}")
label.DrawLatex(0.550, 0.920, "#sqrt{s} = 13 TeV, L_{int} = 59.7 fb^{-1}")

# show interactively
c2.Draw()

# %% [markdown]
# We also print the cut-flow report to investigate the efficiency of the filters.

# %%
# Print cut-flow report
report.Print()
# Out:
# Events where both taus have pT > 50 GeV: pass=17312      all=26940      -- eff=64.26 % cumulative eff=64.26 %

# %% [markdown]
# ### 1.3 Getting help with `ROOT`

# %% [markdown]
# The [`ROOT` website](https://root.cern) is home to the [beginner’s guide](https://root.cern/primer/) and the more in-depth [manual],(https://root.cern/manual/). These are a great resource to start with `ROOT` and learn about parts of the framework in high detail. Keep in mind the [`ROOT` website](https://root.cern), which provides links to all resources in a single place!

# %% [markdown]
# The [reference guide](https://root.cern/doc/master/index.html) provides a more technical documentation about `ROOT` powered by [Doxygen](https://www.doxygen.nl/index.html). You can search for classes or functions in `ROOT`, learn about types and methods and trace features down to the actual implementation.
#
# Although the reference guide is more technical in first place, important classes have extensive additional documentation. Feel free to investigate [`TTree`](https://root.cern/doc/master/classTTree.html) or [`RDataFrame`](https://root.cern/doc/master/classROOT_1_1RDataFrame.html)!
#
# Another part of the reference guide are the [tutorials](https://root.cern/doc/master/group__Tutorials.html), which explain features in working code examples. Feel free to look at tutorials for [`RooFit`](https://root.cern/doc/master/group__tutorial__roofit.html) and [`RDataFrame`](https://root.cern/doc/master/group__tutorial__dataframe.html), which cover many typical use cases for these parts of `ROOT`!

# %% [markdown]
# The [`ROOT` forum](https://root-forum.cern.ch/) is the to-go place if you cannot find the answer in the documentation. Don’t hesitate to open a discussion, there is always someone from the `ROOT` team actively taking care of new questions in the forum!
#
# But not only questions are very welcome, you can also discuss possible improvements or make suggestions for new features!

# %% [markdown]
# Bugs are currently tracked on [Jira](https://sft.its.cern.ch/jira/projects/ROOT/summary), but we will soon switch to [GitHub issues](https://github.com/root-project/root). However, if you discover bugs, please report them! In case you are not sure whether you see a bug or a feature, posting in the `ROOT` forum is always a good idea and always appreciated!

# %% [markdown]
# ### 1.4 `TLorentzVector`

# %% [markdown]
# The `TLorentzVector` class in `ROOT` is designed to handle relativistic four-vectors in particle physics. These vectors encode both the momentum (three components: px, py, pz ) and energy (E) of a particle, and can be used to describe the motion of particles moving at relativistic speeds.
#
# We can define a tau lepton with mass $M_\tau = 1.777 GeV$ and initialize it with some momentum components (transverse momentum $p_T=30 GeV$, pseudorapidity $\eta =1.5$, and azimuthal angle $\phi = \pi/2$)

# %%
Mtau = 1.777 #GeV 

# define a TLrentzVector
vect1 = ROOT.TLorentzVector()
# fill it we the information we have
vect1.SetPtEtaPhiM(30,1.5,np.pi/2,Mtau)

# %% [markdown]
# Now that we have set the vector we can compute the variables we might need. For example we could need the mass x, y, z projections of the momentum of the particle, or its energy:

# %%
print('P =', vect1.P(), '; Px =', vect1.Px(), '; Py =', vect1.Py(), '; Pz =', vect1.Pz())
print('E =', vect1.E())
# Out:
# P = 70.57228845729742 ; Px = 1.83697019872103e-15 ; Py = 30.0 ; Pz = 63.87838365284452
# E = 70.59465721355967

# %% [markdown]
# Now suppose we want to reconstruct a particle decaying in two $\tau$ leptons (for example our Higgs boson). Then we would have a second vector for the second $\tau$ lepton:

# %%
vect2 = ROOT.TLorentzVector()
vect2.SetPtEtaPhiE(50,-1.5,-np.pi/2,70.595)

# %% [markdown]
# Then the two vectors of the reconstructed tau leptons should be added together to form the four-vector of the particle we are trying to reconstruct:

# %%
vect = vect1 + vect2

# %% [markdown]
# Let's see what are we reconstructing:

# %%
print('E =', vect.E(), '; M =', vect.M())
# Out:
# E = 141.18965721355966 ; M = 133.1201972088643

# %% [markdown]
# Given the angular configuration of the two $\tau$ leptons that we have defined, and given the E and M of the particle they come from, what can we say about it? How was it produced?

# %% [markdown]
# ### 1.5 For next time

# %% [markdown]
# I would like you to start working with the NTuples I provide you in the folder `SKIMS`. Take these two:
# * `SKIM_GGHH_NLO_cHHH1_xs.root` which contains the signal of double Higgs production trhough gluon fusion
# * `SKIM_TT_fullyHad.root` which contains the biggest background to our analysis
#
# I would like you to this:
# * construct the four-vector for the Higgs candidate decaying into two $\tau$ leptons for both samples
# * plot the distribution of the mass of the Higgs candidates you reconstruct and understand:
#     * why they have such a shape
#     * why are they the same if they are the same and why are they different if they are different
# * fit this distributions of the mass to see if they are consistent with a Higgs boson or if they are not (NB choose the appropriate function)
# * **_ONLY_ IF YOU HAVE HAVE DONE THE ABOVE AND YOU HAVE UNDESTROOD IT**: do the same for the Higgs boson decaying to two b quarks

# %% [markdown]
# You have all the knowledge you need to do this, the only thing you need more is to know how the variables are called in the tree:
# * `dau1_pt` transverse momentum of the first $\tau$ lepton
# * `dau1_eta` eta of the first $\tau$ lepton
# * `dau1_phi` phi of the first $\tau$ lepton
# * `dau1_e` energy of the first $\tau$ lepton

# %% [markdown]
# * `dau2_pt` transverse momentum of the second $\tau$ lepton
# * `dau2_eta` eta of the second $\tau$ lepton
# * `dau2_phi` phi of the second $\tau$ lepton
# * `dau2_e` energy of the second $\tau$ lepton

# %% [markdown]
# * `bjet1_pt` transverse momentum of the first b quark jet
# * `bjet1_eta` eta of the first b quark jet
# * `bjet1_phi` phi of the first b quark jet
# * `bjet1_e` energy of the first b quark jet

# %% [markdown]
# * `bjet2_pt` transverse momentum of the second b quark jet
# * `bjet2_eta` eta of the second b quark jet
# * `bjet2_phi` phi of the second b quark jet
# * `bjet2_e` energy of the second b quark jet

# %% [markdown]
# **WORK TOGETHER, I WOULD LIKE BOTH OF YOU TO ARRIVE WITH THE SAME LEVEL OF KNOWLEDGE OF WHAT YOU HAVE DONE!**

# %% [markdown]
# **LIKE ALWAYS, I AM AVAILABLE FOR ANY PROBLEM OR DOUBT. CONTACT ME ON SKYPE. BUT I ASK YOU TRY AND FIGURE OUT DOUBTS BEFORE ASKING ME**
